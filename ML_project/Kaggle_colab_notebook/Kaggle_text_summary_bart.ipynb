# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/personal/combined_data.csv

# %%
import numpy as np
import pandas as pd 
df = pd.read_csv("/kaggle/input/personal/combined_data.csv")
pd.set_option('display.max_colwidth', None)
df.head(1)
# Out:
#                       Product Name  Rating                      Rating Count  \
# 0  Apple iPhone 15 (Black, 128 GB)     4.6  1,39,977 Ratings & 4,510 Reviews
#
#                                                                                                                                                                                                                   Information  \
# 0  ['128 GB ROM', '15.49 cm (6.1 inch) Super Retina XDR Display', '48MP + 12MP | 12MP Front Camera', 'A16 Bionic Chip, 6 Core Processor Processor', '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories']
#
#      Price  \
# 0  ₹57,999
#
#                                                                                                                                                                                                                                                                                                                                                                                                                href  \
# 0  https://www.flipkart.com/apple-iphone-15-black-128-gb/p/itm6ac6485515ae4?pid=MOBGTAGPTB3VS24W&lid=LSTMOBGTAGPTB3VS24WVZNSC6&marketplace=FLIPKART&q=apple+phone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=Search&iid=479ca7ad-157f-487d-a60c-2c06b8b23e79.MOBGTAGPTB3VS24W.SEARCH&ppt=sp&ppn=sp&ssid=wnnhy0s4h3uy8dfk1728211454850&qH=900bc469862f62c0
#
#      5_star  4_star 3_star 2_star  ... Display_Negative_Score  \
# 0  1,11,018  16,956  3,770  1,923  ...                    3%
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Display_Comments  \
# 0  ['...Battery - Better then other iphones 5/5\nDisplay - Awesome\nPerformance - A little performance drop when', '...When you shift from Android to IPhone 60Hz display; it will not bother you.', '...Upgraded from iPhone XS and it is really great!\nDisplay is very nice except the 60hz', '...The display is bright and sharp, making everything from watching videos to browsing the web a pleasure.', '...phone at this price range.\n\nCamera : 5/5\nDisplay : 5/5\nBattery : 4/5\nPerformance : 5/5\n\nOnly cons', '...Everything is very good in this iPhone, but the only problem I found is that the brightness of the display is a little low.', '...photography experience. Battery backup is good . Display is much better than 14 version.', '...Breakdown:\nPerformance: 5/5\nCameras: 5/5\nDisplay: 5/5\nBattery Life: 4.5/5\nDesign: 4/5\nmiddot; Value:', '...While iphone 15 only has 60hz screen which feels choppy, all other phones have 120-144hz screen which are smooth af.', '...Display: 4.5/5\nPerformance: 4.2/5\nCamera: 4/5\nBattery: 3']
#
#   Design_Overall_Rating Design_Positive_Score Design_Negative_Score  \
# 0                   4.6                  96%                    4%
#
#   Design_Comments Performance_Overall_Rating Performance_Positive_Score  \
# 0         ['N/A']                        4.6                       96%
#
#   Performance_Negative_Score  \
# 0                        4%
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Performance_Comments
# 0  ['...Osm performance', "...The overall device is a power pack of performance ❤️\nAndroid users please don't shift to this (real hassle)", '...Performance is super smooth, with no lag even when running multiple apps.', '...A16 Bionic Chip: Blazing-fast performance handles demanding tasks and games effortlessly.', "...In terms of performance, the processor on the iPhone 15 handles every task I've thrown at it like a dream, including gaming!", '...Smooth performance of IOS system, no lags ,no glitches , not a single problem when you get to use.', '...is fine and will last for one day long.\n3. Performance - iphone 15 performance is super. No lagging and no heating issue.\nCons-\n1', '...This phone is literally beast in performance but yeah I feel 60hz bit less smooth .', '...Truly amazing and smooth processor makes it great experience for user.', '...cant see the difference in performance coz i am not really into games and cpu intensive tasks.']
#
# [1 rows x 37 columns]

# %%
df = df[['Product Name','Information','Camera_Comments','Battery_Comments','Display_Comments','Design_Comments','Performance_Comments']]
df.head(1)
# Out:
#                       Product Name  \
# 0  Apple iPhone 15 (Black, 128 GB)
#
#                                                                                                                                                                                                                   Information  \
# 0  ['128 GB ROM', '15.49 cm (6.1 inch) Super Retina XDR Display', '48MP + 12MP | 12MP Front Camera', 'A16 Bionic Chip, 6 Core Processor Processor', '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Camera_Comments  \
# 0  ['...The camera quality is exceptional, capturing detailed and vivid photos even in low light.', '...The camera upgrades are noticeable, especially in low light, and impressed by the level of detail in every shot.', '...The iPhone 15 flaunts an impressive camera setup, capturing moments with exceptional clarity and detail.', '...Pros:\nSuperb Cameras: The 48MP main sensor captures stunning photos with excellent detail and dynamic range.', '...The iPhone 15, dressed in a mesmerizing shade of blue, boasts exceptional camera prowess, ensuring stellar image quality.', '...The phone is pretty good in terms of camera. However, those who have used 120hz premium', '...The camera quality is unparalleled, capturing every moment with incredible detail and clarity.', '...Loved the inhand feel of the device 😍 Amazing camera qualit', '...The camera system is a standout feature, capturing stunning photos with enhanced low-light capabilities and impressive zoom options.', '...Camera: The 48 MP main camera produces high-quality images, and the automatic portrait mode is a standout feature.']
#
#   Battery_Comments  \
# 0            Error
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Display_Comments  \
# 0  ['...Battery - Better then other iphones 5/5\nDisplay - Awesome\nPerformance - A little performance drop when', '...When you shift from Android to IPhone 60Hz display; it will not bother you.', '...Upgraded from iPhone XS and it is really great!\nDisplay is very nice except the 60hz', '...The display is bright and sharp, making everything from watching videos to browsing the web a pleasure.', '...phone at this price range.\n\nCamera : 5/5\nDisplay : 5/5\nBattery : 4/5\nPerformance : 5/5\n\nOnly cons', '...Everything is very good in this iPhone, but the only problem I found is that the brightness of the display is a little low.', '...photography experience. Battery backup is good . Display is much better than 14 version.', '...Breakdown:\nPerformance: 5/5\nCameras: 5/5\nDisplay: 5/5\nBattery Life: 4.5/5\nDesign: 4/5\nmiddot; Value:', '...While iphone 15 only has 60hz screen which feels choppy, all other phones have 120-144hz screen which are smooth af.', '...Display: 4.5/5\nPerformance: 4.2/5\nCamera: 4/5\nBattery: 3']
#
#   Design_Comments  \
# 0         ['N/A']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Performance_Comments
# 0  ['...Osm performance', "...The overall device is a power pack of performance ❤️\nAndroid users please don't shift to this (real hassle)", '...Performance is super smooth, with no lag even when running multiple apps.', '...A16 Bionic Chip: Blazing-fast performance handles demanding tasks and games effortlessly.', "...In terms of performance, the processor on the iPhone 15 handles every task I've thrown at it like a dream, including gaming!", '...Smooth performance of IOS system, no lags ,no glitches , not a single problem when you get to use.', '...is fine and will last for one day long.\n3. Performance - iphone 15 performance is super. No lagging and no heating issue.\nCons-\n1', '...This phone is literally beast in performance but yeah I feel 60hz bit less smooth .', '...Truly amazing and smooth processor makes it great experience for user.', '...cant see the difference in performance coz i am not really into games and cpu intensive tasks.']

# %%
review_columns = ['Camera_Comments', 'Battery_Comments', 'Display_Comments', 'Design_Comments', 'Performance_Comments']
df['All_Reviews'] = df[review_columns].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
df = df[["Product Name","Information", "All_Reviews"]]
df.tail(1)
# Out:
#                        Product Name  \
# 4876  vivo U20 (Blaze Blue, 128 GB)
#
#                                                                                                          Information  \
# 4876  ['8 GB RAM | 128 GB ROM', '16.59 cm (6.53 inch) Display', '16MP Rear Camera', '5000 mAh Battery', '12 Months']
#
#      All_Reviews
# 4876

# %%
import re
import string
df["All_Reviews"] = df["All_Reviews"].str.lower()
def remove_html_tag(text):
    pattern = re.compile(r'<.*?>')
    return pattern.sub('', text)
def remove_url(text):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub('', text)
def remove_newline(text):
    return text.replace('\n', ' ')
def remove_white_space(text):
    return re.sub(r'\s+', ' ', text)
def remove_punc(text):
    exclude = string.punctuation
    return text.translate(str.maketrans('', '', exclude))
df["All_Reviews"] = df["All_Reviews"].apply(remove_html_tag) 
df["All_Reviews"] = df["All_Reviews"].apply(remove_newline)
df["All_Reviews"] = df["All_Reviews"].apply(remove_url) 
df["All_Reviews"] = df["All_Reviews"].apply(remove_white_space)
df["All_Reviews"] = df["All_Reviews"].apply(remove_punc)
df.head(1)
# Out:
#                       Product Name  \
# 0  Apple iPhone 15 (Black, 128 GB)
#
#                                                                                                                                                                                                                   Information  \
# 0  ['128 GB ROM', '15.49 cm (6.1 inch) Super Retina XDR Display', '48MP + 12MP | 12MP Front Camera', 'A16 Bionic Chip, 6 Core Processor Processor', '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          All_Reviews
# 0  the camera quality is exceptional capturing detailed and vivid photos even in low light the camera upgrades are noticeable especially in low light and impressed by the level of detail in every shot the iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras the 48mp main sensor captures stunning photos with excellent detail and dynamic range the iphone 15 dressed in a mesmerizing shade of blue boasts exceptional camera prowess ensuring stellar image quality the phone is pretty good in terms of camera however those who have used 120hz premium the camera quality is unparalleled capturing every moment with incredible detail and clarity loved the inhand feel of the device 😍 amazing camera qualit the camera system is a standout feature capturing stunning photos with enhanced lowlight capabilities and impressive zoom options camera the 48 mp main camera produces highquality images and the automatic portrait mode is a standout feature error battery  better then other iphones 55ndisplay  awesomenperformance  a little performance drop when when you shift from android to iphone 60hz display it will not bother you upgraded from iphone xs and it is really greatndisplay is very nice except the 60hz the display is bright and sharp making everything from watching videos to browsing the web a pleasure phone at this price rangenncamera  55ndisplay  55nbattery  45nperformance  55nnonly cons everything is very good in this iphone but the only problem i found is that the brightness of the display is a little low photography experience battery backup is good  display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iphone 15 only has 60hz screen which feels choppy all other phones have 120144hz screen which are smooth af display 455nperformance 425ncamera 45nbattery 3 na osm performance the overall device is a power pack of performance ❤️nandroid users please dont shift to this real hassle performance is super smooth with no lag even when running multiple apps a16 bionic chip blazingfast performance handles demanding tasks and games effortlessly in terms of performance the processor on the iphone 15 handles every task ive thrown at it like a dream including gaming smooth performance of ios system no lags no glitches  not a single problem when you get to use is fine and will last for one day longn3 performance  iphone 15 performance is super no lagging and no heating issuenconsn1 this phone is literally beast in performance but yeah i feel 60hz bit less smooth  truly amazing and smooth processor makes it great experience for user cant see the difference in performance coz i am not really into games and cpu intensive tasks

# %%
def remove_emoji(text):
    emoji_pattern = re.compile(
        "["  # Start of character set
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # Chinese characters
        u"\U00002702-\U000027B0"  # Miscellaneous symbols
        u"\U000024C2-\U0001F251"  # Enclosed characters
        u"\U00010000-\U0010FFFF"  # Supplementary characters
        "]+", flags=re.UNICODE)
    
    return emoji_pattern.sub(r'', text)
df["All_Reviews"] = df["All_Reviews"].apply(remove_emoji)
first_row = df.iloc[0]
print(first_row)
# Out:
# Product Name                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Apple iPhone 15 (Black, 128 GB)
# Information                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ['128 GB ROM', '15.49 cm (6.1 inch) Super Retina XDR Display', '48MP + 12MP | 12MP Front Camera', 'A16 Bionic Chip, 6 Core Processor Processor', '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories']
# All_Reviews     the camera quality is exceptional capturing detailed and vivid photos even in low light the camera upgrades are noticeable especially in low light and impressed by the level of detail in every shot the iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras the 48mp main sensor captures stunning photos with excellent detail and dynamic range the iphone 15 dressed in a mesmerizing shade of blue boasts exceptional camera prowess ensuring stellar image quality the phone is pretty good in terms of camera however those who have used 120hz premium the camera quality is unparalleled capturing every moment with incredible detail and clarity loved the inhand feel of the device  amazing camera qualit the camera system is a standout feature capturing stunning photos with enhanced lowlight capabilities and impressive zoom options camera the 48 mp main camera produces highquality images and the automatic portrait mode is a standout feature error battery  better then other iphones 55ndisplay  awesomenperformance  a little performance drop when when you shift from android to iphone 60hz display it will not bother you upgraded from iphone xs and it is really greatndisplay is very nice except the 60hz the display is bright and sharp making everything from watching videos to browsing the web a pleasure phone at this price rangenncamera  55ndisplay  55nbattery  45nperformance  55nnonly cons everything is very good in this iphone but the only problem i found is that the brightness of the display is a little low photography experience battery backup is good  display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iphone 15 only has 60hz screen which feels choppy all other phones have 120144hz screen which are smooth af display 455nperformance 425ncamera 45nbattery 3 na osm performance the overall device is a power pack of performance nandroid users please dont shift to this real hassle performance is super smooth with no lag even when running multiple apps a16 bionic chip blazingfast performance handles demanding tasks and games effortlessly in terms of performance the processor on the iphone 15 handles every task ive thrown at it like a dream including gaming smooth performance of ios system no lags no glitches  not a single problem when you get to use is fine and will last for one day longn3 performance  iphone 15 performance is super no lagging and no heating issuenconsn1 this phone is literally beast in performance but yeah i feel 60hz bit less smooth  truly amazing and smooth processor makes it great experience for user cant see the difference in performance coz i am not really into games and cpu intensive tasks
# Name: 0, dtype: object

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)

# %%
import torch
from transformers import pipeline

# Load the summarization pipeline on GPU
summarizer = pipeline("summarization", model="facebook/bart-large-cnn", device=0)

def summarize_reviews_in_batches(reviews, batch_size=32):
    summaries = []
    for i in range(0, len(reviews), batch_size):
        batch = reviews[i:i+batch_size]
        try:
            results = summarizer(batch, max_length=120, min_length=100, do_sample=False)
            summaries.extend([result['summary_text'] for result in results])
        except Exception as e:
            summaries.extend(["Error in summarization"] * len(batch))
    return summaries

df['reviews_clean'] = df['All_Reviews'].fillna("No review available").apply(lambda x: "No review available" if x.strip() == "" else x)

df['summary'] = summarize_reviews_in_batches(df['reviews_clean'].tolist())
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 119. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 36. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
# Your max_length is set to 120, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 120, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 119. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 115. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Your max_length is set to 120, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# ...
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 120, but your input_length is only 116. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 110. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 120, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 120, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 116. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 117. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 120, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 120, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)

# %%
df.to_csv("/kaggle/working/summarized_data.csv")
df.head()
# Out:
#                           Product Name  \
# 0      Apple iPhone 15 (Black, 128 GB)
# 1       Apple iPhone 15 (Pink, 128 GB)
# 2      Apple iPhone 15 (Green, 128 GB)
# 3       Apple iPhone 15 (Blue, 128 GB)
# 4  Apple iPhone 15 Plus (Blue, 128 GB)
#
#                                                                                                                                                                                                                   Information  \
# 0  ['128 GB ROM', '15.49 cm (6.1 inch) Super Retina XDR Display', '48MP + 12MP | 12MP Front Camera', 'A16 Bionic Chip, 6 Core Processor Processor', '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories']
# 1  ['128 GB ROM', '15.49 cm (6.1 inch) Super Retina XDR Display', '48MP + 12MP | 12MP Front Camera', 'A16 Bionic Chip, 6 Core Processor Processor', '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories']
# 2  ['128 GB ROM', '15.49 cm (6.1 inch) Super Retina XDR Display', '48MP + 12MP | 12MP Front Camera', 'A16 Bionic Chip, 6 Core Processor Processor', '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories']
# 3  ['128 GB ROM', '15.49 cm (6.1 inch) Super Retina XDR Display', '48MP + 12MP | 12MP Front Camera', 'A16 Bionic Chip, 6 Core Processor Processor', '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories']
# 4  ['128 GB ROM', '17.02 cm (6.7 inch) Super Retina XDR Display', '48MP + 12MP | 12MP Front Camera', 'A16 Bionic Chip, 6 Core Processor Processor', '1 Year Warranty for Phone and 6 Months Warranty for In-Box Accessories']
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       All_Reviews  \
# 0  the camera quality is exceptional capturing detailed and vivid photos even in low light the camera upgrades are noticeable especially in low light and impressed by the level of detail in every shot the iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras the 48mp main sensor captures stunning photos with excellent detail and dynamic range the iphone 15 dressed in a mesmerizing shade of blue boasts exceptional camera prowess ensuring stellar image quality the phone is pretty good in terms of camera however those who have used 120hz premium the camera quality is unparalleled capturing every moment with incredible detail and clarity loved the inhand feel of the device  amazing camera qualit the camera system is a standout feature capturing stunning photos with enhanced lowlight capabilities and impressive zoom options camera the 48 mp main camera produces highquality images and the automatic portrait mode is a standout feature error battery  better then other iphones 55ndisplay  awesomenperformance  a little performance drop when when you shift from android to iphone 60hz display it will not bother you upgraded from iphone xs and it is really greatndisplay is very nice except the 60hz the display is bright and sharp making everything from watching videos to browsing the web a pleasure phone at this price rangenncamera  55ndisplay  55nbattery  45nperformance  55nnonly cons everything is very good in this iphone but the only problem i found is that the brightness of the display is a little low photography experience battery backup is good  display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iphone 15 only has 60hz screen which feels choppy all other phones have 120144hz screen which are smooth af display 455nperformance 425ncamera 45nbattery 3 na osm performance the overall device is a power pack of performance nandroid users please dont shift to this real hassle performance is super smooth with no lag even when running multiple apps a16 bionic chip blazingfast performance handles demanding tasks and games effortlessly in terms of performance the processor on the iphone 15 handles every task ive thrown at it like a dream including gaming smooth performance of ios system no lags no glitches  not a single problem when you get to use is fine and will last for one day longn3 performance  iphone 15 performance is super no lagging and no heating issuenconsn1 this phone is literally beast in performance but yeah i feel 60hz bit less smooth  truly amazing and smooth processor makes it great experience for user cant see the difference in performance coz i am not really into games and cpu intensive tasks
# 1  the camera quality is exceptional capturing detailed and vivid photos even in low light the camera upgrades are noticeable especially in low light and impressed by the level of detail in every shot the iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras the 48mp main sensor captures stunning photos with excellent detail and dynamic range the iphone 15 dressed in a mesmerizing shade of blue boasts exceptional camera prowess ensuring stellar image quality the phone is pretty good in terms of camera however those who have used 120hz premium the camera quality is unparalleled capturing every moment with incredible detail and clarity loved the inhand feel of the device  amazing camera qualit the camera system is a standout feature capturing stunning photos with enhanced lowlight capabilities and impressive zoom options camera the 48 mp main camera produces highquality images and the automatic portrait mode is a standout feature error battery  better then other iphones 55ndisplay  awesomenperformance  a little performance drop when when you shift from android to iphone 60hz display it will not bother you upgraded from iphone xs and it is really greatndisplay is very nice except the 60hz the display is bright and sharp making everything from watching videos to browsing the web a pleasure phone at this price rangenncamera  55ndisplay  55nbattery  45nperformance  55nnonly cons everything is very good in this iphone but the only problem i found is that the brightness of the display is a little low photography experience battery backup is good  display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iphone 15 only has 60hz screen which feels choppy all other phones have 120144hz screen which are smooth af display 455nperformance 425ncamera 45nbattery 3 na osm performance the overall device is a power pack of performance nandroid users please dont shift to this real hassle performance is super smooth with no lag even when running multiple apps a16 bionic chip blazingfast performance handles demanding tasks and games effortlessly in terms of performance the processor on the iphone 15 handles every task ive thrown at it like a dream including gaming smooth performance of ios system no lags no glitches  not a single problem when you get to use is fine and will last for one day longn3 performance  iphone 15 performance is super no lagging and no heating issuenconsn1 this phone is literally beast in performance but yeah i feel 60hz bit less smooth  truly amazing and smooth processor makes it great experience for user cant see the difference in performance coz i am not really into games and cpu intensive tasks
# 2  the camera quality is exceptional capturing detailed and vivid photos even in low light the camera upgrades are noticeable especially in low light and impressed by the level of detail in every shot the iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras the 48mp main sensor captures stunning photos with excellent detail and dynamic range the iphone 15 dressed in a mesmerizing shade of blue boasts exceptional camera prowess ensuring stellar image quality the phone is pretty good in terms of camera however those who have used 120hz premium the camera quality is unparalleled capturing every moment with incredible detail and clarity loved the inhand feel of the device  amazing camera qualit the camera system is a standout feature capturing stunning photos with enhanced lowlight capabilities and impressive zoom options camera the 48 mp main camera produces highquality images and the automatic portrait mode is a standout feature error battery  better then other iphones 55ndisplay  awesomenperformance  a little performance drop when when you shift from android to iphone 60hz display it will not bother you upgraded from iphone xs and it is really greatndisplay is very nice except the 60hz the display is bright and sharp making everything from watching videos to browsing the web a pleasure phone at this price rangenncamera  55ndisplay  55nbattery  45nperformance  55nnonly cons everything is very good in this iphone but the only problem i found is that the brightness of the display is a little low photography experience battery backup is good  display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iphone 15 only has 60hz screen which feels choppy all other phones have 120144hz screen which are smooth af display 455nperformance 425ncamera 45nbattery 3 na osm performance the overall device is a power pack of performance nandroid users please dont shift to this real hassle performance is super smooth with no lag even when running multiple apps a16 bionic chip blazingfast performance handles demanding tasks and games effortlessly in terms of performance the processor on the iphone 15 handles every task ive thrown at it like a dream including gaming smooth performance of ios system no lags no glitches  not a single problem when you get to use is fine and will last for one day longn3 performance  iphone 15 performance is super no lagging and no heating issuenconsn1 this phone is literally beast in performance but yeah i feel 60hz bit less smooth  truly amazing and smooth processor makes it great experience for user cant see the difference in performance coz i am not really into games and cpu intensive tasks
# 3  the camera quality is exceptional capturing detailed and vivid photos even in low light the camera upgrades are noticeable especially in low light and impressed by the level of detail in every shot the iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras the 48mp main sensor captures stunning photos with excellent detail and dynamic range the iphone 15 dressed in a mesmerizing shade of blue boasts exceptional camera prowess ensuring stellar image quality the phone is pretty good in terms of camera however those who have used 120hz premium the camera quality is unparalleled capturing every moment with incredible detail and clarity loved the inhand feel of the device  amazing camera qualit the camera system is a standout feature capturing stunning photos with enhanced lowlight capabilities and impressive zoom options camera the 48 mp main camera produces highquality images and the automatic portrait mode is a standout feature error battery  better then other iphones 55ndisplay  awesomenperformance  a little performance drop when when you shift from android to iphone 60hz display it will not bother you upgraded from iphone xs and it is really greatndisplay is very nice except the 60hz the display is bright and sharp making everything from watching videos to browsing the web a pleasure phone at this price rangenncamera  55ndisplay  55nbattery  45nperformance  55nnonly cons everything is very good in this iphone but the only problem i found is that the brightness of the display is a little low photography experience battery backup is good  display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iphone 15 only has 60hz screen which feels choppy all other phones have 120144hz screen which are smooth af display 455nperformance 425ncamera 45nbattery 3 na osm performance the overall device is a power pack of performance nandroid users please dont shift to this real hassle performance is super smooth with no lag even when running multiple apps a16 bionic chip blazingfast performance handles demanding tasks and games effortlessly in terms of performance the processor on the iphone 15 handles every task ive thrown at it like a dream including gaming smooth performance of ios system no lags no glitches  not a single problem when you get to use is fine and will last for one day longn3 performance  iphone 15 performance is super no lagging and no heating issuenconsn1 this phone is literally beast in performance but yeah i feel 60hz bit less smooth  truly amazing and smooth processor makes it great experience for user cant see the difference in performance coz i am not really into games and cpu intensive tasks
# 4                                                                                                                                                         48mp main camera captures detailed and vibrant photos even in low light days till the heating issue is resolvedngood camera and dynamic island flipkart apple seller and delivery team phone is really good camera quality is on next level display is gorgeous performance is really battery backup and also a superb display the camera quality is just fabulous go for it fabulous phonenoutstanding camera qualitynamazing display quality apple didnt improved their camera performance in low light impressive camera the upgraded camera system captures detailed and vibrant photos making it a great choice for photography enthusiasts the camera system upgraded with a 48mp main sensor captures stunning photos and videos the camera system excels in photography and videography offering impressive lowlight capabilities and exceptional image stabilization excellent camera great lowlight and photography features review after 6 months of usennbattery 100 battery health after 221 cyclengaming  no lag bgmi 60fps smooth gaming battery drains fast charging twize a day shame to say its iphone the best thing of this device is battery really i never experience a device with longlasting battery the larger battery ensures you can go about your day without worrying about running out of juice awesome experience and battery performance of this phone is amazing this is the best iphone evernamazing battery backup and very fast chargingncharging cable quality is also best stellar battery life easily the best in the iphone lineup offering two days of usage on a single charge good battery all day battery life with heavy use gamers can buy this battery is good if you are switching from a 6000 mah battery then you will find it little bit less but it still does the work i last charged 95 sat 9 pm and and battery at came to 4 in monday 10pm totally give battery back up 49 hours seamless multitasking and app performancen bright and vibrant display delivers excellent viewing angles and outdoor the display was not in good need of much improvement iphone ncamera  47 starnperformance 5 starndisplay  45 starnbody material  4 starndesing  5 starnsound only problem with the phone is its 60hz display apple product with great display functionalitynngreat to own camera and battery performance is very goodndisplay averagenoverall performance is very nice best phone but 60hz display is very slow touch is behaving abnormally sometimes and display is not so clear usbc charging versatile charging optionsnconsndisplay only 60hz refresh ratenpricey premium cost may not fit all budgets display  smooth animations despite being 60hz display na error
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     reviews_clean  \
# 0  the camera quality is exceptional capturing detailed and vivid photos even in low light the camera upgrades are noticeable especially in low light and impressed by the level of detail in every shot the iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras the 48mp main sensor captures stunning photos with excellent detail and dynamic range the iphone 15 dressed in a mesmerizing shade of blue boasts exceptional camera prowess ensuring stellar image quality the phone is pretty good in terms of camera however those who have used 120hz premium the camera quality is unparalleled capturing every moment with incredible detail and clarity loved the inhand feel of the device  amazing camera qualit the camera system is a standout feature capturing stunning photos with enhanced lowlight capabilities and impressive zoom options camera the 48 mp main camera produces highquality images and the automatic portrait mode is a standout feature error battery  better then other iphones 55ndisplay  awesomenperformance  a little performance drop when when you shift from android to iphone 60hz display it will not bother you upgraded from iphone xs and it is really greatndisplay is very nice except the 60hz the display is bright and sharp making everything from watching videos to browsing the web a pleasure phone at this price rangenncamera  55ndisplay  55nbattery  45nperformance  55nnonly cons everything is very good in this iphone but the only problem i found is that the brightness of the display is a little low photography experience battery backup is good  display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iphone 15 only has 60hz screen which feels choppy all other phones have 120144hz screen which are smooth af display 455nperformance 425ncamera 45nbattery 3 na osm performance the overall device is a power pack of performance nandroid users please dont shift to this real hassle performance is super smooth with no lag even when running multiple apps a16 bionic chip blazingfast performance handles demanding tasks and games effortlessly in terms of performance the processor on the iphone 15 handles every task ive thrown at it like a dream including gaming smooth performance of ios system no lags no glitches  not a single problem when you get to use is fine and will last for one day longn3 performance  iphone 15 performance is super no lagging and no heating issuenconsn1 this phone is literally beast in performance but yeah i feel 60hz bit less smooth  truly amazing and smooth processor makes it great experience for user cant see the difference in performance coz i am not really into games and cpu intensive tasks
# 1  the camera quality is exceptional capturing detailed and vivid photos even in low light the camera upgrades are noticeable especially in low light and impressed by the level of detail in every shot the iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras the 48mp main sensor captures stunning photos with excellent detail and dynamic range the iphone 15 dressed in a mesmerizing shade of blue boasts exceptional camera prowess ensuring stellar image quality the phone is pretty good in terms of camera however those who have used 120hz premium the camera quality is unparalleled capturing every moment with incredible detail and clarity loved the inhand feel of the device  amazing camera qualit the camera system is a standout feature capturing stunning photos with enhanced lowlight capabilities and impressive zoom options camera the 48 mp main camera produces highquality images and the automatic portrait mode is a standout feature error battery  better then other iphones 55ndisplay  awesomenperformance  a little performance drop when when you shift from android to iphone 60hz display it will not bother you upgraded from iphone xs and it is really greatndisplay is very nice except the 60hz the display is bright and sharp making everything from watching videos to browsing the web a pleasure phone at this price rangenncamera  55ndisplay  55nbattery  45nperformance  55nnonly cons everything is very good in this iphone but the only problem i found is that the brightness of the display is a little low photography experience battery backup is good  display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iphone 15 only has 60hz screen which feels choppy all other phones have 120144hz screen which are smooth af display 455nperformance 425ncamera 45nbattery 3 na osm performance the overall device is a power pack of performance nandroid users please dont shift to this real hassle performance is super smooth with no lag even when running multiple apps a16 bionic chip blazingfast performance handles demanding tasks and games effortlessly in terms of performance the processor on the iphone 15 handles every task ive thrown at it like a dream including gaming smooth performance of ios system no lags no glitches  not a single problem when you get to use is fine and will last for one day longn3 performance  iphone 15 performance is super no lagging and no heating issuenconsn1 this phone is literally beast in performance but yeah i feel 60hz bit less smooth  truly amazing and smooth processor makes it great experience for user cant see the difference in performance coz i am not really into games and cpu intensive tasks
# 2  the camera quality is exceptional capturing detailed and vivid photos even in low light the camera upgrades are noticeable especially in low light and impressed by the level of detail in every shot the iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras the 48mp main sensor captures stunning photos with excellent detail and dynamic range the iphone 15 dressed in a mesmerizing shade of blue boasts exceptional camera prowess ensuring stellar image quality the phone is pretty good in terms of camera however those who have used 120hz premium the camera quality is unparalleled capturing every moment with incredible detail and clarity loved the inhand feel of the device  amazing camera qualit the camera system is a standout feature capturing stunning photos with enhanced lowlight capabilities and impressive zoom options camera the 48 mp main camera produces highquality images and the automatic portrait mode is a standout feature error battery  better then other iphones 55ndisplay  awesomenperformance  a little performance drop when when you shift from android to iphone 60hz display it will not bother you upgraded from iphone xs and it is really greatndisplay is very nice except the 60hz the display is bright and sharp making everything from watching videos to browsing the web a pleasure phone at this price rangenncamera  55ndisplay  55nbattery  45nperformance  55nnonly cons everything is very good in this iphone but the only problem i found is that the brightness of the display is a little low photography experience battery backup is good  display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iphone 15 only has 60hz screen which feels choppy all other phones have 120144hz screen which are smooth af display 455nperformance 425ncamera 45nbattery 3 na osm performance the overall device is a power pack of performance nandroid users please dont shift to this real hassle performance is super smooth with no lag even when running multiple apps a16 bionic chip blazingfast performance handles demanding tasks and games effortlessly in terms of performance the processor on the iphone 15 handles every task ive thrown at it like a dream including gaming smooth performance of ios system no lags no glitches  not a single problem when you get to use is fine and will last for one day longn3 performance  iphone 15 performance is super no lagging and no heating issuenconsn1 this phone is literally beast in performance but yeah i feel 60hz bit less smooth  truly amazing and smooth processor makes it great experience for user cant see the difference in performance coz i am not really into games and cpu intensive tasks
# 3  the camera quality is exceptional capturing detailed and vivid photos even in low light the camera upgrades are noticeable especially in low light and impressed by the level of detail in every shot the iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras the 48mp main sensor captures stunning photos with excellent detail and dynamic range the iphone 15 dressed in a mesmerizing shade of blue boasts exceptional camera prowess ensuring stellar image quality the phone is pretty good in terms of camera however those who have used 120hz premium the camera quality is unparalleled capturing every moment with incredible detail and clarity loved the inhand feel of the device  amazing camera qualit the camera system is a standout feature capturing stunning photos with enhanced lowlight capabilities and impressive zoom options camera the 48 mp main camera produces highquality images and the automatic portrait mode is a standout feature error battery  better then other iphones 55ndisplay  awesomenperformance  a little performance drop when when you shift from android to iphone 60hz display it will not bother you upgraded from iphone xs and it is really greatndisplay is very nice except the 60hz the display is bright and sharp making everything from watching videos to browsing the web a pleasure phone at this price rangenncamera  55ndisplay  55nbattery  45nperformance  55nnonly cons everything is very good in this iphone but the only problem i found is that the brightness of the display is a little low photography experience battery backup is good  display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iphone 15 only has 60hz screen which feels choppy all other phones have 120144hz screen which are smooth af display 455nperformance 425ncamera 45nbattery 3 na osm performance the overall device is a power pack of performance nandroid users please dont shift to this real hassle performance is super smooth with no lag even when running multiple apps a16 bionic chip blazingfast performance handles demanding tasks and games effortlessly in terms of performance the processor on the iphone 15 handles every task ive thrown at it like a dream including gaming smooth performance of ios system no lags no glitches  not a single problem when you get to use is fine and will last for one day longn3 performance  iphone 15 performance is super no lagging and no heating issuenconsn1 this phone is literally beast in performance but yeah i feel 60hz bit less smooth  truly amazing and smooth processor makes it great experience for user cant see the difference in performance coz i am not really into games and cpu intensive tasks
# 4                                                                                                                                                         48mp main camera captures detailed and vibrant photos even in low light days till the heating issue is resolvedngood camera and dynamic island flipkart apple seller and delivery team phone is really good camera quality is on next level display is gorgeous performance is really battery backup and also a superb display the camera quality is just fabulous go for it fabulous phonenoutstanding camera qualitynamazing display quality apple didnt improved their camera performance in low light impressive camera the upgraded camera system captures detailed and vibrant photos making it a great choice for photography enthusiasts the camera system upgraded with a 48mp main sensor captures stunning photos and videos the camera system excels in photography and videography offering impressive lowlight capabilities and exceptional image stabilization excellent camera great lowlight and photography features review after 6 months of usennbattery 100 battery health after 221 cyclengaming  no lag bgmi 60fps smooth gaming battery drains fast charging twize a day shame to say its iphone the best thing of this device is battery really i never experience a device with longlasting battery the larger battery ensures you can go about your day without worrying about running out of juice awesome experience and battery performance of this phone is amazing this is the best iphone evernamazing battery backup and very fast chargingncharging cable quality is also best stellar battery life easily the best in the iphone lineup offering two days of usage on a single charge good battery all day battery life with heavy use gamers can buy this battery is good if you are switching from a 6000 mah battery then you will find it little bit less but it still does the work i last charged 95 sat 9 pm and and battery at came to 4 in monday 10pm totally give battery back up 49 hours seamless multitasking and app performancen bright and vibrant display delivers excellent viewing angles and outdoor the display was not in good need of much improvement iphone ncamera  47 starnperformance 5 starndisplay  45 starnbody material  4 starndesing  5 starnsound only problem with the phone is its 60hz display apple product with great display functionalitynngreat to own camera and battery performance is very goodndisplay averagenoverall performance is very nice best phone but 60hz display is very slow touch is behaving abnormally sometimes and display is not so clear usbc charging versatile charging optionsnconsndisplay only 60hz refresh ratenpricey premium cost may not fit all budgets display  smooth animations despite being 60hz display na error
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             summary
# 0                                                      The iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras. The 48mp main sensor captures stunning photos with excellent detail and dynamic range. The automatic portrait mode is a standout feature. The battery backup is good and display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iph one 15 only has 60hz screen which feels choppy.
# 1                                                      The iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras. The 48mp main sensor captures stunning photos with excellent detail and dynamic range. The automatic portrait mode is a standout feature. The battery backup is good and display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iph one 15 only has 60hz screen which feels choppy.
# 2                                                      The iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras. The 48mp main sensor captures stunning photos with excellent detail and dynamic range. The automatic portrait mode is a standout feature. The battery backup is good and display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iph one 15 only has 60hz screen which feels choppy.
# 3                                                      The iphone 15 flaunts an impressive camera setup capturing moments with exceptional clarity and detail prosnsuperb cameras. The 48mp main sensor captures stunning photos with excellent detail and dynamic range. The automatic portrait mode is a standout feature. The battery backup is good and display is much better than 14 version breakdownnperformance 55ncameras 55ndisplay 55nbattery life 455ndesign 45nmiddot value while iph one 15 only has 60hz screen which feels choppy.
# 4  The iPhone 5S has a 48mp main camera system with a 48MP main sensor captures stunning photos and videos. The camera system excels in photography and videography offering impressive lowlight capabilities and exceptional image stabilization. Bright and vibrant display delivers excellent viewing angles and outdoor. 60hz display is very slow touch is behaving abnormally sometimes and display is not so clear usbc charging versatile charging optionsnconsndisplay only 60hz refresh ratenpricey premium cost may not fit all budgets.
